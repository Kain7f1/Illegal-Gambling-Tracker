# %% [markdown]
# ## 라이브러리 설치

# %%
# !pip install selenium==3.14.0
# Out:
# Collecting selenium==3.14.0
#   Using cached selenium-3.14.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3 in c:\users\user\.conda\envs\tc_env\lib\site-packages (from selenium==3.14.0) (2.2.1)
# Using cached selenium-3.14.0-py2.py3-none-any.whl (898 kB)
# Installing collected packages: selenium
# Successfully installed selenium-3.14.0

# %%
# !pip install beautifulsoup4==4.12.2
# Out:
# Requirement already satisfied: beautifulsoup4==4.12.2 in c:\users\user\.conda\envs\tc_env\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\.conda\envs\tc_env\lib\site-packages (from beautifulsoup4==4.12.2) (2.5)

# %% [markdown]
# ## 함수

# %%
# get_driver()
# 사용 전제 조건 : Users 폴더에 버전에 맞는 chromedriver.exe를 다운받아주세요
# 기능 : driver를 반환합니다
# 리턴값 : driver
def get_driver():
    CHROME_DRIVER_PATH = "C:/Users/chromedriver.exe"    # (절대경로) Users 폴더에 chromedriver.exe를 설치했음
    options = webdriver.ChromeOptions()                 # 옵션 선언
    # [옵션 설정]
    options.add_argument("--start-maximized")         # 창이 최대화 되도록 열리게 한다.
    # options.add_argument("--headless")                  # 창이 없이 크롬이 실행이 되도록 만든다
    options.add_argument("disable-infobars")            # 안내바가 없이 열리게 한다.
    options.add_argument("disable-gpu")                 # 크롤링 실행시 GPU를 사용하지 않게 한다.
    options.add_argument("--disable-dev-shm-usage")     # 공유메모리를 사용하지 않는다
    options.add_argument("--blink-settings=imagesEnabled=false")    # 이미지 로딩 비활성화
    options.add_argument('--disk-cache-dir=/path/to/cache-dir')     # 캐시 사용 활성화
    options.page_load_strategy = 'none'             # 전체 페이지가 완전히 로드되기를 기다리지 않고 다음 작업을 수행 (중요)
    options.add_argument('--log-level=3')           # 웹 소켓을 통한 로그 메시지 비활성화
    options.add_argument('--no-sandbox')            # 브라우저 프로파일링 비활성화
    options.add_argument('--disable-plugins')       # 다양한 플러그인 및 기능 비활성화
    options.add_argument('--disable-extensions')    # 다양한 플러그인 및 기능 비활성화
    options.add_argument('--disable-sync')          # 다양한 플러그인 및 기능 비활성화
    driver = webdriver.Chrome(CHROME_DRIVER_PATH, options=options)
    return driver


# get_soup()
# 기능 : url을 받아 requests를 사용하여 soup를 리턴하는 함수입니다
# 특징 : 오류발생 시 재귀하기 때문에, 성공적으로 soup를 받아올 수 있습니다.
def get_soup(url, time_sleep=0, max_retries=600):
    try:
        if max_retries <= 0:
            print("[최대 재시도 횟수 초과 : get_soup()]")
            return None
        with requests.Session() as session:
            response = session.get(url, headers=headers)
            time.sleep(time_sleep)
        soup = BeautifulSoup(response.text, "html.parser")
        if len(soup) == 0:  # 불러오는데 실패하면
            print(f"[soup 로딩 실패, 반복] [get_soup(time_sleep=1)]")
            soup = get_soup(url, 1)
    except Exception as e:
        print(f"[오류 발생, 반복] [get_soup(time_sleep=1)] ", e)
        soup = get_soup(url, 1, max_retries-1)
    return soup

# %% [markdown]
# ## 코드

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import requests
import time

# %%
# 광고 사이트 url 리스트
ad_site_url_list = [
    'https://www.toonko1.com/',
    'https://itrulli.com/',
    'https://xn--hu1b88ll0ffvo7li.info/',
    'https://tvwiki14.com/',
    'https://missvod1.com/',
    'https://nooo1.tv/'
]

# %%
# target_url = 'https://www.toonko1.com/'
target_url = 'https://nooo1.tv/'

# %%
driver = get_driver()
driver.get(target_url)
html = driver.page_source  # html 가져오기
soup = BeautifulSoup(html, 'html.parser')  # bs로 파싱

# a_tags = soup.find_all('a')  # a 태그
# hrefs = [a.get('href') for a in a_tags if a.get('href')]  # None 값 제외

# for href in hrefs:
#     print(href)

# %%
xpath = "/html/body/div/div/div[2]/div[1]/div/a"
element = driver.find_element(By.XPATH, xpath)
element
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21124\2048846287.py in <cell line: 2>()
#       1 xpath = "/html/body/div/div/div[2]/div[1]/div/a"
# ----> 2 element = driver.find_element(By.XPATH, xpath)
#       3 element
#
# ~\.conda\envs\tc_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     962                 by = By.CSS_SELECTOR
#     963                 value = '[name="%s"]' % value
# --> 964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
#     966             'value': value})['value']
#
# ~\.conda\envs\tc_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# ~\.conda\envs\tc_env\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/div/div[2]/div[1]/div/a"}
#   (Session info: chrome=133.0.6943.127)

# %%
html
# Out:
# '<html lang="ko"><head>\n<meta charset="utf-8">\n<meta name="robots" content="index,follow">\n\n<title>누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기</title>\n\n<link rel="icon" sizes="192x192" href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_192%2Ch_192%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" type="image/jpeg">\n<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.css">\n<link rel="stylesheet" href="https://nooo1.tv/js/font-awesome/css/font-awesome.min.css?ver=24080717">\n<link rel="stylesheet" href="https://nooo1.tv/theme/basic/css/util.css?ver=24080717">\n<link href="https://unpkg.com/minibarjs@latest/dist/minibar.min.css" rel="stylesheet" type="text/css">\n<link rel="stylesheet" href="https://nooo1.tv/theme/basic/css/modal.css?ver=24080717">\n<link rel="stylesheet" href="https://nooo1.tv/theme/basic/css/alertify.min.css?ver=24080717">\n<link rel="shortcut icon" href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" type="image/jpeg">\n<link rel="apple-touch-icon" href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_180%2Ch_180%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" type="image/jpeg">\n\n<meta http-equiv="imagetoolbar" content="no">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<meta name="description" content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다.">\n<meta name="keywords" content="누누티비, 티비 다시보기, 영화 다시보기, 드라마 다시보기,">\n<meta name="author" content="누누티비">\n<meta property="og:title" content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기">\n<meta property="og:description" content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다.">\n<meta property="og:image" content="https://nooo1.tv/theme/basic/img/sns_logo.jpg">\n<meta property="og:image:width" content="1000">\n<meta property="og:image:height" content="500">\n<meta property="og:url" content="https://nooo1.tv/">\n<meta property="og:site_name" content="누누티비">\n<meta property="og:type" content="website">\n<meta name="robots" content="index,follow">\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:title" content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기">\n<meta name="twitter:description" content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다.">\n<meta name="twitter:image" content="https://nooo1.tv/theme/basic/img/sns_logo.jpg">\n\n<meta name="google-site-verification" content="YWt1LknzDPnz4MUrkrLWjGk1-rTqXBe4HAUD2fBo9aM">\n<link rel="stylesheet" href="https://nooo1.tv/theme/basic/css/default.css?ver=24080717">\n<!--[if lte IE 8]>\n<script src="https://nooo1.tv/js/html5.js"></script>\n<![endif]-->\n<script src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" async="" type="text/javascript"></script><script src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" async="" type="text/javascript"></script><script src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" async="" type="text/javascript"></script><script src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" async="" type="text/javascript"></script><script>\n// 자바스크립트에서 사용하는 전역변수 선언\nvar g5_url       = "https://nooo1.tv";\nvar g5_bbs_url   = "https://nooo1.tv/bbs";\nvar g5_is_member = "";\nvar g5_is_admin  = "";\nvar g5_is_mobile = "";\nvar g5_bo_table  = "";\nvar g5_sca       = "";\nvar g5_editor    = "";\nvar g5_cookie_domain = "";\nvar g5_theme_shop_url = "https://nooo1.tv/theme/basic/shop";\nvar g5_shop_url = "https://nooo1.tv/shop";\n</script>\n\n\n<script type="application/ld+json">\n{\n    "@context": "https://schema.or ...

# %%
soup
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="index,follow" name="robots"/>
# <title>누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기</title>
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_192%2Ch_192%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="icon" sizes="192x192" type="image/jpeg"/>
# <link href="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.css" rel="stylesheet"/>
# <link href="https://nooo1.tv/js/font-awesome/css/font-awesome.min.css?ver=24080717" rel="stylesheet"/>
# <link href="https://nooo1.tv/theme/basic/css/util.css?ver=24080717" rel="stylesheet"/>
# <link href="https://unpkg.com/minibarjs@latest/dist/minibar.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://nooo1.tv/theme/basic/css/modal.css?ver=24080717" rel="stylesheet"/>
# <link href="https://nooo1.tv/theme/basic/css/alertify.min.css?ver=24080717" rel="stylesheet"/>
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="shortcut icon" type="image/jpeg"/>
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_180%2Ch_180%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="apple-touch-icon" type="image/jpeg"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." name="description"/>
# <meta content="누누티비, 티비 다시보기, 영화 다시보기, 드라마 다시보기," name="keywords"/>
# <meta content="누누티비" name="author"/>
# <meta content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기" property="og:title"/>
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." property="og:description"/>
# <meta content="https://nooo1.tv/theme/basic/img/sns_logo.jpg" property="og:image"/>
# <meta content="1000" property="og:image:width"/>
# <meta content="500" property="og:image:height"/>
# <meta content="https://nooo1.tv/" property="og:url"/>
# <meta content="누누티비" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="index,follow" name="robots"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기" name="twitter:title"/>
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." name="twitter:description"/>
# <meta content="https://nooo1.tv/theme/basic/img/sns_logo.jpg" name="twitter:image"/>
# <meta content="YWt1LknzDPnz4MUrkrLWjGk1-rTqXBe4HAUD2fBo9aM" name="google-site-verification"/>
# <link href="https://nooo1.tv/theme/basic/css/default.css?ver=24080717" rel="stylesheet"/>
# <!--[if lte IE 8]>
# <script src="https://nooo1.tv/js/html5.js"></script>
# <![endif]-->
# <script async="" src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" type="text/javascript"></script><script async="" src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" type="text/javascript"></script><script async="" src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" type="text/javascript"></script><script async="" src="//e.dtscout.com/e/?v=1a&amp;pid=5200&amp;site=1&amp;l=https%3A%2F%2Fnooo1.tv%2F&amp;j=" type="text/javascript"></script><script>
# // 자바스크립트에서 사용하는 전역변수 선언
# var g5_url       = "https://nooo1.tv";
# var g5_bbs_url   = "https://nooo1.tv/bbs";
# var g5_is_member = "";
# var g5_is_admin  = "";
# var g5_is_mobile = "";
# var g5_bo_table  = "";
# var g5_sca       = "";
# var g5_editor    = "";
# var g5_cookie_domain = "";
# var g5_theme_shop_url = "https://nooo1.tv/theme/basic/shop";
# var g5_shop_url = "https://nooo1.tv/shop";
# </script>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "url": "https://nooo1.tv",
#     "logo": "https://nooo1.tv/theme/basic/img/pc/header/logo.png"
#  }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "WebSite",
#     "name": "누누티비",
#     "url": "https://nooo1.tv",
#     "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://nooo1.tv/nnnn/search.php?stx={search_term_string}",
#         "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <script src="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.js"></script>
# <script src="https://nooo1.tv/js/jquery-2.2.4.min.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/jquery-migrate-1.4.1.min.js?ver=24080717"></script>
# <script src="https://code.iconify.design/3/3.0.0/iconify.min.js"></script>
# <script src="https://nooo1.tv/js/jquery.menu.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/common.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/wrest.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/placeholders.min.js?ver=24080717"></script>
# <script src="https://unpkg.com/minibarjs@latest/dist/minibar.min.js" type="text/javascript"></script>
# <script src="https://nooo1.tv/theme/basic/js/modal.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/alertify.min.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/common.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/nice-select.js?ver=24080717"></script>
# <script async="" src="//s10.histats.com/js15_as.js" type="text/javascript"></script><script async="" src="//s10.histats.com/js15_as.js" type="text/javascript"></script></head>
# <body>
# <div id="app">
# <div id="header">
# <div class="col-logo">
# <div class="logo-inner">
# <div class="folding-menu">
# <button class="folding"><svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:round-menu" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M4 18h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1s.45 1 1 1m0-5h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1s.45 1 1 1M3 7c0 .55.45 1 1 1h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1" fill="currentColor"></path></svg></button>
# </div>
# <div class="logo">
# <h1><a href="/" title="누누티비"><img alt="누누티비" src="https://nooo1.tv/theme/basic/img/pc/header/logo.png" width="110"/></a></h1>
# </div>
# </div>
# </div>
# <div class="col-search">
# <div class="search-inner">
# <form action="/nnnn/search.php" id="search" method="get" name="fSearchBox">
# <div class="search-form">
# <input autocomplete="off" class="search-input" name="stx" placeholder="검색어를 입력해주세요" type="text" value=""/>
# <div class="search-res">
# <button class="submit" type="submit">
# <svg aria-hidden="true" class="iconify iconify--material-symbols" data-icon="material-symbols:search" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="m19.6 21l-6.3-6.3q-.75.6-1.725.95T9.5 16q-2.725 0-4.612-1.888T3 9.5t1.888-4.612T9.5 3t4.613 1.888T16 9.5q0 1.1-.35 2.075T14.7 13.3l6.3 6.3zM9.5 14q1.875 0 3.188-1.312T14 9.5t-1.312-3.187T9.5 5T6.313 6.313T5 9.5t1.313 3.188T9.5 14" fill="currentColor"></path></svg>
# <span class="blind">검색</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="col-extra">
# <div class="extra-inner">
# <div class="member-action">
# <a href="/bbs/login.php">로그인</a>
# <a href="/bbs/register_form.php">회원가입</a>
# </div>
# </div>
# </div>
# </div>
# <div id="aside">
# <div class="scrolling-box mb-container" id="scrolling-box" style="position: relative;"><div class="mb-track mb-track-x"><div class="mb-bar" style="width: 210px;"></div></div><div class="mb-track mb-track-y"><div class="mb-bar" style="height: 753px; top: 0px;"></div></div><div class="mb-content" style="overflow-y: auto; margin-right: -17px;">
# <div class="home-menu">
# <div class="rows">
# <a href="/" target="_self">
# <svg aria-hidden="true" class="iconify iconify--material-symbols" data-icon="material-symbols:home-outline" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M6 19h3v-6h6v6h3v-9l-6-4.5L6 10zm-2 2V9l8-6l8 6v12h-7v-6h-2v6zm8-8.75" fill="currentColor"></path></svg>
# <strong>홈</strong>
# </a>
# </div>
# <div class="rows">
# <a href="/all/program_list.php" target="_self">
# <svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:round-list-alt" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M12 9h4c.55 0 1-.45 1-1s-.45-1-1-1h-4c-.55 0-1 .45-1 1s.45 1 1 1m0 4h4c.55 0 1-.45 1-1s-.45-1-1-1h-4c-.55 0-1 .45-1 1s.45 1 1 1m0 4h4c.55 0 1-.45 1-1s-.45-1-1-1h-4c-.55 0-1 .45-1 1s.45 1 1 1M7 7h2v2H7zm0 4h2v2H7zm0 4h2v2H7zM20 3H4c-.55 0-1 .45-1 1v16c0 .55.45 1 1 1h16c.55 0 1-.45 1-1V4c0-.55-.45-1-1-1m-1 16H5V5h14z" fill="currentColor"></path></svg>
# <strong>전체보기</strong>
# </a>
# </div>
# <div class="rows">
# <a href="/nnnn/popular_list.php">
# <svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:outline-star-outline" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="m22 9.24l-7.19-.62L12 2L9.19 8.63L2 9.24l5.46 4.73L5.82 21L12 17.27L18.18 21l-1.63-7.03zM12 15.4l-3.76 2.27l1-4.28l-3.32-2.88l4.38-.38L12 6.1l1.71 4.04l4.38.38l-3.32 2.88l1 4.28z" fill="currentColor"></path></svg>
# <strong>인기영상</strong>
# </a>
# </div>
# </div>
# <div class="main-menu">
# <div class="menu-list">
# <div class="menu">
# <h2><svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:outline-local-movies" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M14 5v14h-4V5zm6-2h-2v2h-2V3H8v2H6V3H4v18h2v-2h2v2h8v-2h2v2h2zm-4 6V7h2v2zM6 9V7h2v2zm10 4v-2h2v2zM6 13v-2h2v2zm10 4v-2h2v2zM6 17v-2h2v2z" fill="currentColor"></path></svg><strong>영화</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=kr_movie">한국영화</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=en_movie">해외영화</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ani_movie">[극장판] 에니메이션</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><svg aria-hidden="true" class="iconify iconify--material-symbols" data-icon="material-symbols:tv-gen-outline" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M4 21v-2q-.825 0-1.412-.587T2 17V6q0-.825.588-1.412T4 4h16q.825 0 1.413.588T22 6v11q0 .825-.587 1.413T20 19v2h-1l-.65-2H5.675L5 21zm0-4h16V6H4zm8-5.5" fill="currentColor"></path></svg><strong>방송프로그램</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=drama">드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=en_drama">해외드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=entertainment">예능프로그램</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=documentary">다큐/시사</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=animation">에니메이션</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><svg aria-hidden="true" class="iconify iconify--mdi" data-icon="mdi:film-star-outline" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M13 19c0 .34.04.67.09 1H4a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h1l2 4h3L8 4h2l2 4h3l-2-4h2l2 4h3l-2-4h4v9.81c-.61-.35-1.28-.59-2-.72V10H5.76L4 6.47V18h9.09c-.05.33-.09.66-.09 1m10-1.11l-2.89-.25L19 15l-1.13 2.64l-2.87.25l2.18 1.88l-.68 2.81l2.5-1.49l2.45 1.49l-.65-2.81z" fill="currentColor"></path></svg><strong>OTT</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=ott_drama">OTT 드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ott_entertainment">OTT 예능</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ott_documentary">OTT 다큐</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><svg aria-hidden="true" class="iconify iconify--mdi" data-icon="mdi:film-star-outline" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M13 19c0 .34.04.67.09 1H4a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h1l2 4h3L8 4h2l2 4h3l-2-4h2l2 4h3l-2-4h4v9.81c-.61-.35-1.28-.59-2-.72V10H5.76L4 6.47V18h9.09c-.05.33-.09.66-.09 1m10-1.11l-2.89-.25L19 15l-1.13 2.64l-2.87.25l2.18 1.88l-.68 2.81l2.5-1.49l2.45 1.49l-.65-2.81z" fill="currentColor"></path></svg><strong>추억의 저장소</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=old_drama">추억의 드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=old_entertainment">추억의 예능</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="home-menu">
# <div class="rows">
# <a href="/nnnn/history_list.php">
# <svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:outline-timer" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M15 1H9v2h6zm-4 13h2V8h-2zm8.03-6.61l1.42-1.42c-.43-.51-.9-.99-1.41-1.41l-1.42 1.42A8.96 8.96 0 0 0 12 4c-4.97 0-9 4.03-9 9s4.02 9 9 9a8.994 8.994 0 0 0 7.03-14.61M12 20c-3.87 0-7-3.13-7-7s3.13-7 7-7s7 3.13 7 7s-3.13 7-7 7" fill="currentColor"></path></svg>
# <strong>시청기록</strong>
# </a>
# </div>
# </div>
# </div></div>
# </div>
# <div id="container">
# <div class="sec-policy-1">
# <div class="inner">
# <a class="sec-1" href="https://info.nooo2.tv" target="_blank">
#                     접속 차단에 관한 새로운 주소 대피관련 안내
#                     <svg aria-hidden="true" class="iconify iconify--ic" data-icon="ic:outline-keyboard-arrow-right" height="1em" role="img" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M8.59 16.59L13.17 12L8.59 7.41L10 6l6 6l-6 6z" fill="currentColor"></path></svg>
# </a>
# </div>
# </div>
# <div class="sec-policy-2">
# <div class="inner">
# <a class="sec-1" href="javascript:void(0);">
#                     2023.12.14 공식 도메인 주소가 변경되었습니다 - nooo2.tv 참고 바랍니다.
#                 </a>
# </div>
# </div>
# <div class="content">
# <div class="content-banner">
# </div>
# <div id="index">
# <div class="suggession main">
# <iframe allowfullscreen="true" allowtransparency="true" class="movie-frame" frameborder="0" height="650" id="movie-frame" scrolling="no" src="/nnnn/player.php" width="100%"></iframe>
# </div>
# <div class="suggession">
# </div>
# </div>
# <script>
#             var swiper1 = new Swiper('.swiper-latest-movie', {
#                 freeMode: true,
#                 slidesPerView: 'auto',
#                 spaceBetween: 0,
#                 pagination: { el: '.swiper-pagination', dynamicBullets: true, },
#                 navigation: { nextEl: '.swiper-button-next', prevEl: '.swiper-button-prev'},
#             });
#             var swiper2 = new Swiper('.swiper-latest-series', {
#                 freeMode: true,
#                 slidesPerView: 'auto',
#                 spaceBetween: 0,
#             });
#         </script>
# </div>
# <div id="footer">
# <div class="notice-content">
# <div class="inner">
# </div>
# </div>
# <div class="footer-content">
# <div class="link-list">
# <a class="liner" href="#"><span>사이트 소개</span></a>
# <a class="liner" href="#"><span>이용약관</span></a>
# <a class="liner" href="#"><span>개인정보 취급방침</span></a>
# <a class="liner" href="#"><span>고객센터</span></a>
# <a class="liner" href="#" rel="modal:open nofollow"><span>자료요청</span></a>
# <a class="liner" href="/?device=mobile" rel="nofollow"><span>모바일 버전</span></a>
# <a class="liner" href="#" rel="nofollow"><span>저작권 보호센터</span></a>
# </div>
# <div class="copyright">
# <p>누누티비 서비스는 해외에 설립된 무료 스트리밍 서비스입니다 자료요청은 언제나 환영하며 요청 페이지에서 접수 가능합니다.</p>
# <p>회사명 : Marti Estudio 사업장 주소 : Caballero 1376, Asunción, Paraguay 연락처 : +595 985 493322</p>
# <p>광고문의 :  nunutv1@protonmail.com</p>
# <p>Copyright © 누누티비 All right reserved.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="window-scroll" id="window-scroll">
# <a href="#">
# <svg aria-hidden="true" class="iconify iconify--ph" data-icon="ph:triangle-fill" height="1em" role="img" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M236.78 211.81A24.34 24.34 0 0 1 215.45 224H40.55a24.34 24.34 0 0 1-21.33-12.19a23.51 23.51 0 0 1 0-23.72l87.43-151.87a24.76 24.76 0 0 1 42.7 0l87.45 151.87a23.51 23.51 0 0 1-.02 23.72" fill="currentColor"></path></svg>
# </a>
# </div>
# <script>
#     new MiniBar('#scrolling-box', { barType: "default", minBarSize: 0, hideBars: true, /* v0.4.0 and above */ alwaysShowBars: false, horizontalMouseScroll: false, scrollX: false, scrollY: true, navButtons: false, scrollAmount: 10, mutationObserver: { attributes: false, childList: true, subtree: true }, /* v0.4.0 and above */ onInit: function() { /* do something on init */ }, /* v0.4.0 and above */ onUpdate: function() { /* do something on update */ }, /* v0.4.0 and above */ onScroll: function() { /* do something on init */ }, });
#
#     $('#member-profile').click(function() {
#         $('#member-profile-fold').toggleClass('open');
#     });
#
#     $(window).scroll(function(e) {
#         if(window.pageYOffset > 100) {
#             $('#window-scroll').show();
#         } else {
#             $('#window-scroll').hide();
#         }
#     });
# </script>
# <!-- Histats.com  START  (aync)-->
# <script type="text/javascript">var _Hasync= _Hasync|| [];
# _Hasync.push(['Histats.start', '1,4836419,4,0,0,0,00010000']);
# _Hasync.push(['Histats.fasi', '1']);
# _Hasync.push(['Histats.track_hits', '']);
# (function() {
# var hs = document.createElement('script'); hs.type = 'text/javascript'; hs.async = true;
# hs.src = ('//s10.histats.com/js15_as.js');
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(hs);
# })();</script>
# <noscript><a href="/" target="_blank"><img alt="web counter" border="0" src="//sstatic1.histats.com/0.gif?4836419&amp;101"/></a></noscript>
# <!-- Histats.com  END  --> |
# <!-- } 하단 끝 -->
# <script src="https://cdn.jsdelivr.net/npm/less"></script>
# <!-- Histats.com  START  (aync)-->
# <script type="text/javascript">var _Hasync= _Hasync|| [];
# _Hasync.push(['Histats.start', '1,4857452,4,0,0,0,00010000']);
# _Hasync.push(['Histats.fasi', '1']);
# _Hasync.push(['Histats.track_hits', '']);
# (function() {
# var hs = document.createElement('script'); hs.type = 'text/javascript'; hs.async = true;
# hs.src = ('//s10.histats.com/js15_as.js');
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(hs);
# })();</script>
# <noscript><a href="/" target="_blank"><img alt="histats.com" border="0" src="//sstatic1.histats.com/0.gif?4857452&amp;101"/></a></noscript>
# <!-- Histats.com  END  -->
# <script async="" src="https://s4.histats.com/stats/0.php?4836419&amp;@f16&amp;@g1&amp;@h1&amp;@i1&amp;@j1740497667124&amp;@k0&amp;@l1&amp;@m%EB%88%84%EB%88%84%ED%8B%B0%EB%B9%84%20-%20%ED%8B%B0%EB%B9%84%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EC%98%81%ED%99%94%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EB%93%9C%EB%9D%BC%EB%A7%88%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0&amp;@n0&amp;@o1000&amp;@q0&amp;@r0&amp;@s0&amp;@tko-KR&amp;@u1920&amp;@b1:-100498281&amp;@b3:1740497667&amp;@b4:js15_as.js&amp;@b5:540&amp;@a-_0.2.1&amp;@vhttps%3A%2F%2Fnooo1.tv%2F&amp;@w" type="text/javascript"></script><script async="" src="https://s4.histats.com/stats/0.php?4857452&amp;@f16&amp;@g1&amp;@h1&amp;@i1&amp;@j1740497667124&amp;@k0&amp;@l1&amp;@m%EB%88%84%EB%88%84%ED%8B%B0%EB%B9%84%20-%20%ED%8B%B0%EB%B9%84%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EC%98%81%ED%99%94%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EB%93%9C%EB%9D%BC%EB%A7%88%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0&amp;@n0&amp;@o1000&amp;@q0&amp;@r0&amp;@s0&amp;@tko-KR&amp;@u1920&amp;@b1:-164913055&amp;@b3:1740497667&amp;@b4:js15_as.js&amp;@b5:540&amp;@a-_0.2.1&amp;@vhttps%3A%2F%2Fnooo1.tv%2F&amp;@w" type="text/javascript"></script><script async="" src="https://s4.histats.com/stats/0.php?4836419&amp;@f16&amp;@g0&amp;@h2&amp;@i1&amp;@j1740497667126&amp;@k2&amp;@l2&amp;@m%EB%88%84%EB%88%84%ED%8B%B0%EB%B9%84%20-%20%ED%8B%B0%EB%B9%84%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EC%98%81%ED%99%94%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EB%93%9C%EB%9D%BC%EB%A7%88%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0&amp;@n0&amp;@o1000&amp;@q0&amp;@r0&amp;@s0&amp;@tko-KR&amp;@u1920&amp;@b1:-22181126&amp;@b3:1740497667&amp;@b4:js15_as.js&amp;@b5:540&amp;@a-_0.2.1&amp;@vhttps%3A%2F%2Fnooo1.tv%2F&amp;@w" type="text/javascript"></script><script async="" src="https://s4.histats.com/stats/0.php?4857452&amp;@f16&amp;@g0&amp;@h2&amp;@i1&amp;@j1740497667126&amp;@k2&amp;@l2&amp;@m%EB%88%84%EB%88%84%ED%8B%B0%EB%B9%84%20-%20%ED%8B%B0%EB%B9%84%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EC%98%81%ED%99%94%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0%2C%20%EB%93%9C%EB%9D%BC%EB%A7%88%20%EB%8B%A4%EC%8B%9C%EB%B3%B4%EA%B8%B0&amp;@n0&amp;@o1000&amp;@q0&amp;@r0&amp;@s0&amp;@tko-KR&amp;@u1920&amp;@b1:63506886&amp;@b3:1740497667&amp;@b4:js15_as.js&amp;@b5:540&amp;@a-_0.2.1&amp;@vhttps%3A%2F%2Fnooo1.tv%2F&amp;@w" type="text/javascript"></script><iframe height="0" src="https://t.dtscout.com/idg/?su=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="0"></iframe><script async="" src="https://p.dtsan.net/dtsa.js"></script><iframe height="0" src="https://t.dtscout.com/idg/?su=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="0"></iframe><script async="" src="https://p.dtsan.net/dtsa.js"></script><iframe height="0" src="https://t.dtscout.com/idg/?su=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="0"></iframe><script async="" src="https://p.dtsan.net/dtsa.js"></script><iframe height="0" src="https://t.dtscout.com/idg/?su=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="0"></iframe><script async="" src="https://p.dtsan.net/dtsa.js"></script><script async="" src="https://tags.crwdcntrl.net/lt/c/3825/lt.min.js"></script><img border="0" height="1" src="https://pixel.onaudience.com/?partner=137085098&amp;mapped=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="1"/><script async="" src="https://t.dtscdn.com/widget/?d=6D001740497667FB1A51CC5E1A7F13F3&amp;nid=300&amp;p=2114454483&amp;t=-540&amp;s=1920x1080x24&amp;u=https%3A%2F%2Fnooo1.tv%2F&amp;r="></script><img border="0" height="1" src="https://pixel.onaudience.com/?partner=137085098&amp;mapped=6D001740497667FB1A51CC5E1A7F13F3" style="display: none;" width="1"/><script async="" src="https://t.dtscdn.com/widget/?d=6D001740497667FB1A51CC5E1A7F13F3&amp;nid=300&amp;p=2114454483&amp;t=-540&amp;s=1920x1080x24&amp;u=https%3A%2F%2Fnooo1.tv%2F&amp;r="></script><img border="0" height="1" src="https://pixel.onaudience.com/?partner= ...

# %%
if "body" in str(html):
    print("a")
# Out:
# a

# %%
hrefs
# Out:
# []

# %%
driver.quit()

# %%
headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36",
        "Connection": "keep-alive",
        "Cache-Control": "max-age=0",
        "sec-ch-ua-mobile": "?0",
        "DNT": "1",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        "Sec-Fetch-Site": "none",
        "Sec-Fetch-Mode": "navigate",
        "Sec-Fetch-User": "?1",
        "Sec-Fetch-Dest": "document",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "ko-KR,ko;q=0.9"
    }

target_url = 'https://nooo1.tv/'
soup = get_soup(target_url)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="index,follow" name="robots">
# <title>누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기</title>
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_192%2Ch_192%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="icon" sizes="192x192" type="image/jpeg"/>
# <link href="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.css" rel="stylesheet"/>
# <link href="https://nooo1.tv/js/font-awesome/css/font-awesome.min.css?ver=24080717" rel="stylesheet"/>
# <link href="https://nooo1.tv/theme/basic/css/util.css?ver=24080717" rel="stylesheet"/>
# <link href="https://unpkg.com/minibarjs@latest/dist/minibar.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://nooo1.tv/theme/basic/css/modal.css?ver=24080717" rel="stylesheet"/>
# <link href="https://nooo1.tv/theme/basic/css/alertify.min.css?ver=24080717" rel="stylesheet"/>
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="shortcut icon" type="image/jpeg">
# <link href="https://static.wixstatic.com/media/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg/v1/fill/w_180%2Ch_180%2Clg_1%2Cusm_0.66_1.00_0.01/857b8c_dcd7ba8fc7cd4752b2bc5af0d0e711a3%7Emv2.jpg" rel="apple-touch-icon" type="image/jpeg">
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." name="description">
# <meta content="누누티비, 티비 다시보기, 영화 다시보기, 드라마 다시보기," name="keywords">
# <meta content="누누티비" name="author"/>
# <meta content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기" property="og:title">
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." property="og:description"/>
# <meta content="https://nooo1.tv/theme/basic/img/sns_logo.jpg" property="og:image"/>
# <meta content="1000" property="og:image:width"/>
# <meta content="500" property="og:image:height"/>
# <meta content="https://nooo1.tv/" property="og:url"/>
# <meta content="누누티비" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="index,follow" name="robots"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="누누티비 - 티비 다시보기, 영화 다시보기, 드라마 다시보기" name="twitter:title"/>
# <meta content="누누티비는 영화 및 드라마를 다시보기 할 수 있는 사이트입니다. 실시간으로 업데이트되는 누누티비만의 다양한 콘텐츠를 검색해보시기 바랍니다." name="twitter:description"/>
# <meta content="https://nooo1.tv/theme/basic/img/sns_logo.jpg" name="twitter:image"/>
# <meta content="YWt1LknzDPnz4MUrkrLWjGk1-rTqXBe4HAUD2fBo9aM" name="google-site-verification"/>
# <link href="https://nooo1.tv/theme/basic/css/default.css?ver=24080717" rel="stylesheet"/>
# <!--[if lte IE 8]>
# <script src="https://nooo1.tv/js/html5.js"></script>
# <![endif]-->
# <script>
# // 자바스크립트에서 사용하는 전역변수 선언
# var g5_url       = "https://nooo1.tv";
# var g5_bbs_url   = "https://nooo1.tv/bbs";
# var g5_is_member = "";
# var g5_is_admin  = "";
# var g5_is_mobile = "";
# var g5_bo_table  = "";
# var g5_sca       = "";
# var g5_editor    = "";
# var g5_cookie_domain = "";
# var g5_theme_shop_url = "https://nooo1.tv/theme/basic/shop";
# var g5_shop_url = "https://nooo1.tv/shop";
# </script>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "url": "https://nooo1.tv",
#     "logo": "https://nooo1.tv/theme/basic/img/pc/header/logo.png"
#  }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "WebSite",
#     "name": "누누티비",
#     "url": "https://nooo1.tv",
#     "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://nooo1.tv/nnnn/search.php?stx={search_term_string}",
#         "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <script src="https://cdn.jsdelivr.net/npm/swiper@8/swiper-bundle.min.js"></script>
# <script src="https://nooo1.tv/js/jquery-2.2.4.min.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/jquery-migrate-1.4.1.min.js?ver=24080717"></script>
# <script src="https://code.iconify.design/3/3.0.0/iconify.min.js"></script>
# <script src="https://nooo1.tv/js/jquery.menu.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/common.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/wrest.js?ver=24080717"></script>
# <script src="https://nooo1.tv/js/placeholders.min.js?ver=24080717"></script>
# <script src="https://unpkg.com/minibarjs@latest/dist/minibar.min.js" type="text/javascript"></script>
# <script src="https://nooo1.tv/theme/basic/js/modal.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/alertify.min.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/common.js?ver=24080717"></script>
# <script src="https://nooo1.tv/theme/basic/js/nice-select.js?ver=24080717"></script>
# </meta></meta></meta></link></link></meta></head>
# <body>
# <div id="app">
# <div id="header">
# <div class="col-logo">
# <div class="logo-inner">
# <div class="folding-menu">
# <button class="folding"><span class="iconify" data-icon="ic:round-menu"></span></button>
# </div>
# <div class="logo">
# <h1><a href="/" title="누누티비"><img alt="누누티비" src="https://nooo1.tv/theme/basic/img/pc/header/logo.png" width="110"/></a></h1>
# </div>
# </div>
# </div>
# <div class="col-search">
# <div class="search-inner">
# <form action="/nnnn/search.php" id="search" method="get" name="fSearchBox">
# <div class="search-form">
# <input autocomplete="off" class="search-input" name="stx" placeholder="검색어를 입력해주세요" type="text" value=""/>
# <div class="search-res">
# <button class="submit" type="submit">
# <span class="iconify" data-icon="material-symbols:search"></span>
# <span class="blind">검색</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="col-extra">
# <div class="extra-inner">
# <div class="member-action">
# <a href="/bbs/login.php">로그인</a>
# <a href="/bbs/register_form.php">회원가입</a>
# </div>
# </div>
# </div>
# </div>
# <div id="aside">
# <div class="scrolling-box" id="scrolling-box">
# <div class="home-menu">
# <div class="rows">
# <a href="/" target="_self">
# <span class="iconify" data-icon="material-symbols:home-outline"></span>
# <strong>홈</strong>
# </a>
# </div>
# <div class="rows">
# <a href="/all/program_list.php" target="_self">
# <span class="iconify" data-icon="ic:round-list-alt"></span>
# <strong>전체보기</strong>
# </a>
# </div>
# <div class="rows">
# <a href="/nnnn/popular_list.php">
# <span class="iconify" data-icon="ic:outline-star-outline"></span>
# <strong>인기영상</strong>
# </a>
# </div>
# </div>
# <div class="main-menu">
# <div class="menu-list">
# <div class="menu">
# <h2><span class="iconify" data-icon="ic:outline-local-movies"></span><strong>영화</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=kr_movie">한국영화</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=en_movie">해외영화</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ani_movie">[극장판] 에니메이션</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><span class="iconify" data-icon="material-symbols:tv-gen-outline"></span><strong>방송프로그램</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=drama">드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=en_drama">해외드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=entertainment">예능프로그램</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=documentary">다큐/시사</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=animation">에니메이션</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><span class="iconify" data-icon="mdi:film-star-outline"></span><strong>OTT</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=ott_drama">OTT 드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ott_entertainment">OTT 예능</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=ott_documentary">OTT 다큐</a></li>
# </ul>
# </div>
# </div>
# <div class="menu-list">
# <div class="menu">
# <h2><span class="iconify" data-icon="mdi:film-star-outline"></span><strong>추억의 저장소</strong></h2>
# <ul>
# <li class=""><a href="/nnnn/program_list.php?section=old_drama">추억의 드라마</a></li>
# <li class=""><a href="/nnnn/program_list.php?section=old_entertainment">추억의 예능</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="home-menu">
# <div class="rows">
# <a href="/nnnn/history_list.php">
# <span class="iconify" data-icon="ic:outline-timer"></span>
# <strong>시청기록</strong>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div id="container">
# <div class="sec-policy-1">
# <div class="inner">
# <a class="sec-1" href="https://info.nooo2.tv" target="_blank">
#                     접속 차단에 관한 새로운 주소 대피관련 안내
#                     <span class="iconify" data-icon="ic:outline-keyboard-arrow-right"></span>
# </a>
# </div>
# </div>
# <div class="sec-policy-2">
# <div class="inner">
# <a class="sec-1" href="javascript:void(0);">
#                     2023.12.14 공식 도메인 주소가 변경되었습니다 - nooo2.tv 참고 바랍니다.
#                 </a>
# </div>
# </div>
# <div class="content">
# <div class="content-banner">
# </div>
# <div id="index">
# <div class="suggession main">
# <iframe allowfullscreen="true" allowtransparency="true" class="movie-frame" frameborder="0" height="650" id="movie-frame" scrolling="no" src="/nnnn/player.php" width="100%"></iframe>
# </div>
# <div class="suggession">
# </div>
# </div>
# <script>
#             var swiper1 = new Swiper('.swiper-latest-movie', {
#                 freeMode: true,
#                 slidesPerView: 'auto',
#                 spaceBetween: 0,
#                 pagination: { el: '.swiper-pagination', dynamicBullets: true, },
#                 navigation: { nextEl: '.swiper-button-next', prevEl: '.swiper-button-prev'},
#             });
#             var swiper2 = new Swiper('.swiper-latest-series', {
#                 freeMode: true,
#                 slidesPerView: 'auto',
#                 spaceBetween: 0,
#             });
#         </script>
# </div>
# <div id="footer">
# <div class="notice-content">
# <div class="inner">
# </div>
# </div>
# <div class="footer-content">
# <div class="link-list">
# <a class="liner" href="#"><span>사이트 소개</span></a>
# <a class="liner" href="#"><span>이용약관</span></a>
# <a class="liner" href="#"><span>개인정보 취급방침</span></a>
# <a class="liner" href="#"><span>고객센터</span></a>
# <a class="liner" href="#" rel="modal:open nofollow"><span>자료요청</span></a>
# <a class="liner" href="/?device=mobile" rel="nofollow"><span>모바일 버전</span></a>
# <a class="liner" href="#" rel="nofollow"><span>저작권 보호센터</span></a>
# </div>
# <div class="copyright">
# <p>누누티비 서비스는 해외에 설립된 무료 스트리밍 서비스입니다 자료요청은 언제나 환영하며 요청 페이지에서 접수 가능합니다.</p>
# <p>회사명 : Marti Estudio 사업장 주소 : Caballero 1376, Asunción, Paraguay 연락처 : +595 985 493322</p>
# <p>광고문의 :  nunutv1@protonmail.com</p>
# <p>Copyright © 누누티비 All right reserved.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="window-scroll" id="window-scroll">
# <a href="#">
# <span class="iconify" data-icon="ph:triangle-fill"></span>
# </a>
# </div>
# <script>
#     new MiniBar('#scrolling-box', { barType: "default", minBarSize: 0, hideBars: true, /* v0.4.0 and above */ alwaysShowBars: false, horizontalMouseScroll: false, scrollX: false, scrollY: true, navButtons: false, scrollAmount: 10, mutationObserver: { attributes: false, childList: true, subtree: true }, /* v0.4.0 and above */ onInit: function() { /* do something on init */ }, /* v0.4.0 and above */ onUpdate: function() { /* do something on update */ }, /* v0.4.0 and above */ onScroll: function() { /* do something on init */ }, });
#
#     $('#member-profile').click(function() {
#         $('#member-profile-fold').toggleClass('open');
#     });
#
#     $(window).scroll(function(e) {
#         if(window.pageYOffset > 100) {
#             $('#window-scroll').show();
#         } else {
#             $('#window-scroll').hide();
#         }
#     });
# </script>
# <!-- Histats.com  START  (aync)-->
# <script type="text/javascript">var _Hasync= _Hasync|| [];
# _Hasync.push(['Histats.start', '1,4836419,4,0,0,0,00010000']);
# _Hasync.push(['Histats.fasi', '1']);
# _Hasync.push(['Histats.track_hits', '']);
# (function() {
# var hs = document.createElement('script'); hs.type = 'text/javascript'; hs.async = true;
# hs.src = ('//s10.histats.com/js15_as.js');
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(hs);
# })();</script>
# <noscript><a href="/" target="_blank"><img alt="web counter" border="0" src="//sstatic1.histats.com/0.gif?4836419&amp;101"/></a></noscript>
# <!-- Histats.com  END  --> |
# <!-- } 하단 끝 -->
# <script src="https://cdn.jsdelivr.net/npm/less"></script>
# <!-- Histats.com  START  (aync)-->
# <script type="text/javascript">var _Hasync= _Hasync|| [];
# _Hasync.push(['Histats.start', '1,4857452,4,0,0,0,00010000']);
# _Hasync.push(['Histats.fasi', '1']);
# _Hasync.push(['Histats.track_hits', '']);
# (function() {
# var hs = document.createElement('script'); hs.type = 'text/javascript'; hs.async = true;
# hs.src = ('//s10.histats.com/js15_as.js');
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(hs);
# })();</script>
# <noscript><a href="/" target="_blank"><img alt="histats.com" border="0" src="//sstatic1.histats.com/0.gif?4857452&amp;101"/></a></noscript>
# <!-- Histats.com  END  -->
# </body>
# </html>
